# %%
import pandas as pd

# %%
df=pd.read_csv('/content/internship.csv')

# %%
df
# Out:
#     categories                                        Description
# 0     politics  The election results were announced late last ...
# 1     politics     The Senate passed a new law on climate change.
# 2     politics  The candidate gave an inspiring speech at the ...
# 3     politics  Voters turned out in record numbers during the...
# 4     politics  Political campaigns have become increasingly d...
# ..         ...                                                ...
# 699     others  Surge in Hacking Attacks Poses Threat to Globa...
# 700     others  Scientists Uncover New Insights Into the Forma...
# 701     others  New Research Suggests Exercise May Help Combat...
# 702     others  Surge in Wild Animal Trafficking Sparks Global...
# 703     others  New Smartphone App Promises to Revolutionize P...
#
# [704 rows x 2 columns]

# %%
df.head()
# Out:
#   categories                                        Description
# 0   politics  The election results were announced late last ...
# 1   politics     The Senate passed a new law on climate change.
# 2   politics  The candidate gave an inspiring speech at the ...
# 3   politics  Voters turned out in record numbers during the...
# 4   politics  Political campaigns have become increasingly d...

# %%
# !pip install nltk

# %%
from sklearn.model_selection import train_test_split

# Assuming you have your sentences and corresponding labels in two lists
sentences = df['Description']  # List of your sentences
labels = df['categories']     # List of corresponding labels (e.g., 'Politics', 'Natural Disasters', 'Positive/Uplifting')

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sentences, labels, test_size=0.2, random_state=42)

# test_size=0.2 means 20% of the data will be used for testing, and 80% for training
# random_state is set for reproducibility

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Sample DataFrame (replace this with your actual DataFrame)

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Initialize the Support Vector Machine model
svm_model = SVC(kernel='linear')  # You can also try 'rbf', 'poly', etc.


svm_model.fit(X_train_tfidf, y_train)


y_pred = svm_model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
print(f"SVM Model Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# SVM Model Accuracy: 0.9716
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#    Natural Disaster       1.00      0.95      0.97        20
# Possitive/Uplifting       0.88      0.96      0.92        24
#             Protest       1.00      0.92      0.96        13
#           Terrorism       1.00      1.00      1.00        26
#              others       1.00      0.94      0.97        16
#            politics       0.96      1.00      0.98        26
#               riots       1.00      1.00      1.00        16
#
#            accuracy                           0.97       141
#           macro avg       0.98      0.97      0.97       141
#        weighted avg       0.97      0.97      0.97       141

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def lemmatize_input(user_input):
    doc = nlp(user_input)
    return ' '.join([token.lemma_ for token in doc])

# Function to classify user input
def classify_input(user_input):
    # Lemmatize the user input
    lemmatized_input = lemmatize_input(user_input)
    # Transform the user input to the same TF-IDF feature space
    user_input_tfidf = vectorizer.transform([lemmatized_input])
    # Predict the class
    prediction = svm_model.predict(user_input_tfidf)
    return prediction[0]  # Return the predicted class

# Get user input for classification
while True:
    user_input = input("\nEnter a sentence to classify (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break
    predicted_class = classify_input(user_input)
    print(f"Predicted Class: {predicted_class}")

# %%
import string
import joblib  # Import joblib for saving/loading the model

# %%
joblib.dump(svm_model, 'svm_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']
